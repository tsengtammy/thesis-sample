# %% [markdown]
# # This file: Cleans CA school enrollment data at school level
# # Dependencies: Raw data from CA DOE website
# # Outputs: enrollment (school-level enrollment data, district info, county pop)
# # Last updated: 2/21/2019

# %%
import os
import numpy as np
import pandas as pd
import statsmodels.api as sm
import statsmodels.formula.api as smf
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
# Out:
# /Users/tsengtammy/anaconda/lib/python3.5/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
directory = '/Users/tsengtammy/Dropbox/3 TT/4. Thesis/build/data/input/CA_school_districts'
os.chdir(directory)

# %% [markdown]
# # Merge the raw CA public school enrollment files

# %% [markdown]
# Documentation:
#
# - 'Year' is the first year in the academic calendar - e.g. 1981 means data from the 1981-82 AY.
# - Enrollment by racial/ethnic designation was not collected during the 1982–83 and 1983–84 data collection.
# - Ethnic group names were revised in 1998-99 to meet federal standards.

# %%
sd = pd.DataFrame()

for filename in os.listdir(directory):
    
    if filename.endswith('txt') and len(filename)==9:
        year = filename[3:5]
        
        if int(year) < 20:
            append_year = int('20' + year)
        else:
            append_year = int('19' + year)
        
        df = pd.read_csv(filename, delimiter='\t', dtype={'CDS_CODE':object})
        df['YEAR'] = append_year
        
        sd = sd.append(df)

    # 81 to 92 file
    elif filename.endswith('txt') and filename.startswith('enr'):
        df = pd.read_csv(filename, delimiter='\t', dtype={'CDS_CODE':object, 'COUNTY':object, 'DISTRICT':object,
                                                         'DistrictName':object, 'SCHOOL':object, 'SchoolName':object})
        df['YEAR'] = df['YEAR'].apply(lambda x: int('19' + str(x)[:2]))
        sd = sd.append(df)

# %%
sd.head(10)
# Out:
#    ADULT        CDS_CODE COUNTY DISTRICT DistrictName  ENR_TOTAL ETHNIC  \
# 0      0  01100170130401    NaN      NaN          NaN          1      1
# 1      0  01100170130401    NaN      NaN          NaN          1      2
# 2      0  01100170130401    NaN      NaN          NaN         23      2
# 3      0  01100170130401    NaN      NaN          NaN          3      3
# 4      0  01100170130401    NaN      NaN          NaN          2      4
# 5      0  01100170130401    NaN      NaN          NaN          9      5
# 6      0  01100170130401    NaN      NaN          NaN         77      5
# 7      0  01100170130401    NaN      NaN          NaN         46      6
# 8      0  01100170130401    NaN      NaN          NaN        262      6
# 9      0  01100170130401    NaN      NaN          NaN          6      7
#
#   GENDER  GR_1  GR_10  ...   GR_6  GR_7  GR_8  GR_9  KDGN  SCHOOL  SchoolName  \
# 0      M     0      0  ...      0     0     1     0     0     NaN         NaN
# 1      F     0      0  ...      0     0     0     0     0     NaN         NaN
# 2      M     0      5  ...      0     0     0     4     0     NaN         NaN
# 3      M     0      0  ...      0     1     0     0     0     NaN         NaN
# 4      M     0      0  ...      0     0     0     0     0     NaN         NaN
# 5      F     0      4  ...      0     0     0     3     0     NaN         NaN
# 6      M     0     15  ...      0     1     3    14     0     NaN         NaN
# 7      F     0     10  ...      0     1     4     8     0     NaN         NaN
# 8      M     0     54  ...      2     2    15    32     0     NaN         NaN
# 9      F     0      2  ...      0     0     1     0     0     NaN         NaN
#
#    UNGR_ELM  UNGR_SEC  YEAR
# 0         0         0  2000
# 1         0         0  2000
# 2         0         0  2000
# 3         0         0  2000
# 4         0         0  2000
# 5         0         0  2000
# 6         0         0  2000
# 7         0         0  2000
# 8         0         0  2000
# 9         0         0  2000
#
# [10 rows x 26 columns]

# %%
ethnic_dict_93 = {
    1: 'American Indian or Alaska',
    2: 'Asian',
    3: 'Pacific Islander',
    4: 'Filipino',
    5: 'Hispanic or Latino',
    6: 'Black, not Hispanic',
    7: 'White, not Hispanic'
}

# need to check this, but prob correct...
ethnic_dict_81 = {
    'I': 'American Indian or Alaska',
    'A': 'Asian',
    'P': 'Pacific Islander',
    'F': 'Filipino',
    'H': 'Hispanic or Latino',
    'B': 'Black, not Hispanic',
    'H': 'White, not Hispanic'
}

# %%
sd['ETHNIC_CAT'] = sd.apply(lambda x: ethnic_dict_93.get(x['ETHNIC']) if x['YEAR'] > 1992 else ethnic_dict_81.get(x['ETHNIC']), axis=1)

# %%
# Save file
sd.to_csv('/Users/tsengtammy/Dropbox/3 TT/4. Thesis/build/data/intermediate/school_districts_clean.csv', index=False)

# %% [markdown]
# # Merge w district information

# %%
sd = pd.read_csv('/Users/tsengtammy/Dropbox/3 TT/4. Thesis/build/data/intermediate/school_districts_clean.csv', 
                 dtype={'CDS_CODE':object})
# Out:
# /Users/tsengtammy/anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (2,3,4,6,21,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
sd['CD Code'] = sd['CDS_CODE'].apply(lambda x: x[:7])

# %%
dist = pd.read_csv('/Users/tsengtammy/Dropbox/3 TT/4. Thesis/build/data/input/CA_school_districts/pubschls.txt', 
                   delimiter='\t', dtype={'CDSCode':object})

# %%
dist.head()
# Out:
#          CDS_CODE NCESDist NCESSchool StatusType   County  \
# 0  01100170000000  0691051    No Data     Active  Alameda
# 1  01100170109835  0691051      10546     Closed  Alameda
# 2  01100170112607  0691051      10947     Active  Alameda
# 3  01100170118489  0691051      12283     Closed  Alameda
# 4  01100170123968  0691051      12844     Active  Alameda
#
#                              District  \
# 0  Alameda County Office of Education
# 1  Alameda County Office of Education
# 2  Alameda County Office of Education
# 3  Alameda County Office of Education
# 4  Alameda County Office of Education
#
#                                           School  \
# 0                                        No Data
# 1                            FAME Public Charter
# 2         Envision Academy for Arts & Technology
# 3  Aspire California College Preparatory Academy
# 4        Community School for Creative Education
#
#                              Street                      StreetAbr      City  \
# 0            313 West Winton Avenue           313 West Winton Ave.   Hayward
# 1  39899 Balentine Drive, Suite 335  39899 Balentine Dr., Ste. 335    Newark
# 2               1515 Webster Street               1515 Webster St.   Oakland
# 3             2125 Jefferson Avenue            2125 Jefferson Ave.  Berkeley
# 4      2111 International Boulevard       2111 International Blvd.   Oakland
#
#       ...     AdmFName1 AdmLName1  \
# 0     ...       L Karen    Monroe
# 1     ...       No Data   No Data
# 2     ...           Eve    Gordon
# 3     ...       No Data   No Data
# 4     ...       Monique   Brinson
#
#                                           AdmEmail1 AdmFName2 AdmLName2  \
# 0                                 lkmonroe@acoe.org   No Data   No Data
# 1                                           No Data   No Data   No Data
# 2                           eve@envisionacademy.org   No Data   No Data
# 3                                           No Data   No Data   No Data
# 4  moniqueb@communityschoolforcreativeeducation.org   No Data   No Data
#
#   AdmEmail2 AdmFName3 AdmLName3 AdmEmail3  LastUpDate
# 0   No Data   No Data   No Data   No Data  02/02/2017
# 1   No Data   No Data   No Data   No Data  09/01/2015
# 2   No Data   No Data   No Data   No Data  07/26/2017
# 3   No Data   No Data   No Data   No Data  07/01/2015
# 4   No Data   No Data   No Data   No Data  08/16/2017
#
# [5 rows x 49 columns]

# %%
dist.rename(columns={'CDSCode':'CDS_CODE'}, inplace=True)
dist = dist[['CDS_CODE', 'NCESDist', 'NCESSchool', 'StatusType', 'County', 'District', 'School', 'DOC', 'DOCType']]

# %%
print(len(sd))
print(sd['CDS_CODE'].nunique())
print(len(dist))
print(dist['CDS_CODE'].nunique())
# Out:
# 3534277
# 14737
# 18004
# 18004

# %%
merged = sd.merge(dist, on='CDS_CODE', how='left')

# %%
merged.head()
# Out:
#    ADULT        CDS_CODE COUNTY DISTRICT DistrictName  ENR_TOTAL ETHNIC  \
# 0      0  01100170130401    NaN      NaN          NaN          1      1
# 1      0  01100170130401    NaN      NaN          NaN          1      2
# 2      0  01100170130401    NaN      NaN          NaN         23      2
# 3      0  01100170130401    NaN      NaN          NaN          3      3
# 4      0  01100170130401    NaN      NaN          NaN          2      4
#
#   GENDER  GR_1  GR_10                ...                 \
# 0      M     0      0                ...
# 1      F     0      0                ...
# 2      M     0      5                ...
# 3      M     0      0                ...
# 4      M     0      0                ...
#
#                   ETHNIC_CAT  CD Code  NCESDist  NCESSchool  StatusType  \
# 0  American Indian or Alaska  0110017   0691051       09264      Active
# 1                      Asian  0110017   0691051       09264      Active
# 2                      Asian  0110017   0691051       09264      Active
# 3           Pacific Islander  0110017   0691051       09264      Active
# 4                   Filipino  0110017   0691051       09264      Active
#
#     County                            District  \
# 0  Alameda  Alameda County Office of Education
# 1  Alameda  Alameda County Office of Education
# 2  Alameda  Alameda County Office of Education
# 3  Alameda  Alameda County Office of Education
# 4  Alameda  Alameda County Office of Education
#
#                                School  DOC                           DOCType
# 0  Alameda County Juvenile Hall/Court  0.0  County Office of Education (COE)
# 1  Alameda County Juvenile Hall/Court  0.0  County Office of Education (COE)
# 2  Alameda County Juvenile Hall/Court  0.0  County Office of Education (COE)
# 3  Alameda County Juvenile Hall/Court  0.0  County Office of Education (COE)
# 4  Alameda County Juvenile Hall/Court  0.0  County Office of Education (COE)
#
# [5 rows x 36 columns]

# %%
merged[merged['County'].isna()]
# Out:
#          ADULT        CDS_CODE COUNTY DISTRICT DistrictName  ENR_TOTAL ETHNIC  \
# 2689         0  01612596001788    NaN      NaN          NaN         14      2
# 2690         0  01612596001788    NaN      NaN          NaN         12      2
# 2691         0  01612596001788    NaN      NaN          NaN         10      3
# 2692         0  01612596001788    NaN      NaN          NaN         17      3
# 2693         0  01612596001788    NaN      NaN          NaN          2      4
# 2694         0  01612596001788    NaN      NaN          NaN          1      4
# 2695         0  01612596001788    NaN      NaN          NaN        257      5
# 2696         0  01612596001788    NaN      NaN          NaN        284      5
# 2697         0  01612596001788    NaN      NaN          NaN        314      6
# 2698         0  01612596001788    NaN      NaN          NaN        316      6
# 2699         0  01612596001788    NaN      NaN          NaN          1      7
# 2700         0  01612596001788    NaN      NaN          NaN          3      7
# 2701         0  01612596001788    NaN      NaN          NaN          1      8
# 2702         0  01612596001788    NaN      NaN          NaN          6      8
# 2948         0  01612596002000    NaN      NaN          NaN          2      1
# 2949         0  01612596002000    NaN      NaN          NaN          2      2
# 2950         0  01612596002000    NaN      NaN          NaN          2      2
# 2951         0  01612596002000    NaN      NaN          NaN          2      3
# 2952         0  01612596002000    NaN      NaN          NaN        223      5
# 2953         0  01612596002000    NaN      NaN          NaN        223      5
# 2954         0  01612596002000    NaN      NaN          NaN          4      6
# 2955         0  01612596002000    NaN      NaN          NaN          4      6
# 2956         0  01612596002000    NaN      NaN          NaN          5      7
# 2957         0  01612596002000    NaN      NaN          NaN          4      7
# 4360         0  03322760330027    NaN      NaN          NaN          2      1
# 4361         2  03322760330027    NaN      NaN          NaN         11      2
# 4362         5  03322760330027    NaN      NaN          NaN         32      4
# 4363         2  03322760330027    NaN      NaN          NaN         11      5
# 4364         1  03322760330027    NaN      NaN          NaN          4      6
# 6580         0  07617540731380    NaN      NaN          NaN          7      1
# ...        ...             ...    ...      ...          ...        ...    ...
# 3532036      0  56725876055602    NaN      NaN          NaN         35      7
# 3532037      0  56725876055610    NaN      NaN          NaN          3      2
# 3532038      0  56725876055610    NaN      NaN          NaN          1      2
# 3532039      0  56725876055610    NaN      NaN          NaN        136      5
# 3532040      0  56725876055610    NaN      NaN          NaN        147      5
# 3532041      0  56725876055610    NaN      NaN          NaN          1      6
# 3532042      0  56725876055610    NaN      NaN          NaN          3      6
# 3532043      0  56725876055610    NaN      NaN          NaN         74      7
# 3532044      0  56725876055610    NaN      NaN          NaN         93      7
# 3532048      0  56725955635776    NaN      NaN          NaN          1      1
# 3532049      0  56725955635776    NaN      NaN          NaN          3      2
# 3532050      0  56725955635776    NaN      NaN          NaN        592      5
# 3532051      0  56725955635776    NaN      NaN          NaN        628      5
# 3532052      0  56725955635776    NaN      NaN          NaN          2      6
# 3532053      0  56725955635776    NaN      NaN          NaN        138      7
# 3532054      0  56725955635776    NaN      NaN          NaN        141      7
# 3532055      0  56725955636170    NaN      NaN          NaN         47      5
# 3532056      0  56725955636170    NaN      NaN          NaN         61      5
# 3532057      0  56725955636170    NaN      NaN          NaN          7      7
# 3532058      0  56725955636170    NaN      NaN          NaN          6      7
# 3532993      0  56737596055974    NaN      NaN          NaN         10      2
# 3532994      0  56737596055974    NaN      NaN          NaN          7      2
# 3532995      0  56737596055974    NaN      NaN          NaN          1      4
# 3532996      0  56737596055974    NaN      NaN          NaN         11      5
# 3532997      0  56737596055974    NaN      NaN          NaN         18      5
# 3532998      0  56737596055974    NaN      NaN          NaN          1      6
# 3532999      0  56737596055974    NaN      NaN          NaN          2      6
# 3533000      0  56737596055974    NaN      NaN          NaN        179      7
# 3533001      0  56737596055974    NaN      NaN          NaN        196      7
# 3533002      0  56737596055974    NaN      NaN          NaN          4      8
#
#         GENDER  GR_1  GR_10   ...                    ETHNIC_CAT  CD Code  \
# 2689         F     2      0   ...                         Asian  0161259
# 2690         M     1      0   ...                         Asian  0161259
# 2691         F     2      0   ...              Pacific Islander  0161259
# 2692         M     4      0   ...              Pacific Islander  0161259
# 2693         F     0      0   ...                      Filipino  0161259
# 2694         M     0      0   ...                      Filipino  0161259
# 2695         F    58      0   ...            Hispanic or Latino  0161259
# 2696         M    51      0   ...            Hispanic or Latino  0161259
# 2697         F    52      0   ...           Black, not Hispanic  0161259
# 2698         M    51      0   ...           Black, not Hispanic  0161259
# 2699         F     1      0   ...           White, not Hispanic  0161259
# 2700         M     0      0   ...           White, not Hispanic  0161259
# 2701         F     1      0   ...                           NaN  0161259
# 2702         M     2      0   ...                           NaN  0161259
# 2948         M     1      0   ...     American Indian or Alaska  0161259
# 2949         F     0      0   ...                         Asian  0161259
# 2950         M     0      0   ...                         Asian  0161259
# 2951         M     0      0   ...              Pacific Islander  0161259
# 2952         F    44      0   ...            Hispanic or Latino  0161259
# 2953         M    31      0   ...            Hispanic or Latino  0161259
# 2954         F     0      0   ...           Black, not Hispanic  0161259
# 2955         M     1      0   ...           Black, not Hispanic  0161259
# 2956         F     2      0   ...           White, not Hispanic  0161259
# 2957         M     1      0   ...           White, not Hispanic  0161259
# 4360         M     0      1   ...     American Indian or Alaska  0332276
# 4361         M     0      2   ...                         Asian  0332276
# 4362         M     0      5   ...                      Filipino  0332276
# 4363         M     0      5   ...            Hispanic or Latino  0332276
# 4364         M     0      1   ...           Black, not Hispanic  0332276
# 6580         F     0      2   ...     American Indian or Alaska  0761754
# ...        ...   ...    ...   ...                           ...      ...
# 3532036      M     3      0   ...           White, not Hispanic  5672587
# 3532037      F     2      0   ...                         Asian  5672587
# 3532038      M     0      0   ...                         Asian  5672587
# 3532039      F    23      0   ...            Hispanic or Latino  5672587
# 3532040      M    27      0   ...            Hispanic or Latino  5672587
# 3532041      F     0      0   ...           Black, not Hispanic  5672587
# 3532042      M     0      0   ...           Black, not Hispanic  5672587
# 3532043      F    15      0   ...           White, not Hispanic  5672587
# 3532044      M    13      0   ...           White, not Hispanic  5672587
# 3532048      M     0      0   ...     American Indian or Alaska  5672595
# 3532049      F     0      0   ...                         Asian  5672595
# 3532050      F     0    157   ...            Hispanic or Latino  5672595
# 3532051      M     0    168   ...            Hispanic or Latino  5672595
# 3532052      F     0      1   ...           Black, not Hispanic  5672595
# 3532053      F     0     33   ...           White, not Hispanic  5672595
# 3532054      M     0     26   ...           White, not Hispanic  5672595
# 3532055      F     0      9   ...            Hispanic or Latino  5672595
# 3532056      M     0      9   ...            Hispanic or Latino  5672595
# 3532057      F     0      0   ...           White, not Hispanic  5672595
# 3532058      M     0      1   ...           White, not Hispanic  5672595
# 3532993      F     2      0   ...                         Asian  5673759
# 3532994      M     2      0   ...                         Asian  5673759
# 3532995      M     0      0   ...                      Filipino  5673759
# 3532996      F     2      0   ...            Hispanic or Latino  5673759
# 3532997      M     1      0   ...            Hispanic or Latino  5673759
# 3532998      F     1      0   ...           Black, not Hispanic  5673759
# 3532999      M     1      0   ...           Black, not Hispanic  5673759
# 3533000      F    33      0   ...           White, not Hispanic  5673759
# 3533001      M    30      0   ...           White, not Hispanic  5673759
# 3533002      M     0      0   ...                           NaN  5673759
#
#          NCESDist  NCESSchool  StatusType  County  District  School  DOC  \
# 2689          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2690          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2691          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2692          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2693          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2694          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2695          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2696          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2697          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2698          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2699          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2700          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2701          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2702          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2948          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2949          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2950          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2951          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2952          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2953          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2954          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2955          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2956          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 2957          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 4360          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 4361          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 4362          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 4363          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 4364          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 6580          NaN         NaN         NaN     NaN       NaN     NaN  NaN
# ...           ...         ...         ...     ...       ...     ...  ...
# 3532036       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532037       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532038       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532039       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532040       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532041       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532042       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532043       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532044       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532048       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532049       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532050       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532051       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532052       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532053       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532054       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532055       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532056       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532057       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532058       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532993       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532994       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532995       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532996       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532997       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532998       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3532999       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3533000       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3533001       NaN         NaN         NaN     NaN       NaN     NaN  NaN
# 3533002       NaN         NaN         NaN     NaN       NaN     NaN  NaN
#
#          DOCType
# 2689         NaN
# 2690         NaN
# 2691         NaN
# 2692         NaN
# 2693         NaN
# 2694         NaN
# 2695         NaN
# 2696         NaN
# 2697         NaN
# 2698         NaN
# 2699         NaN
# 2700         NaN
# 2701         NaN
# 2702         NaN
# 2948         NaN
# 2949         NaN
# 2950         NaN
# 2951         NaN
# 2952         NaN
# 2953         NaN
# 2954         NaN
# 2955         NaN
# 2956         NaN
# 2957         NaN
# 4360         NaN
# 4361         NaN
# 4362         NaN
# 4363         NaN
# 4364         NaN
# 6580         NaN
# ...          ...
# 3532036      NaN
# 3532037      NaN
# 3532038      NaN
# 3532039      NaN
# 3532040      NaN
# 3532041      NaN
# 3532042      NaN
# 3532043      NaN
# 3532044      NaN
# 3532048      NaN
# 3532049      NaN
# 3532050      NaN
# 3532051      NaN
# 3532052      NaN
# 3532053      NaN
# 3532054      NaN
# 3532055      NaN
# 3532056      NaN
# 3532057      NaN
# 3532058      NaN
# 3532993      NaN
# 3532994      NaN
# 3532995      NaN
# 3532996      NaN
# 3532997      NaN
# 3532998      NaN
# 3532999      NaN
# 3533000      NaN
# 3533001      NaN
# 3533002      NaN
#
# [74444 rows x 36 columns]

# %% [markdown]
# # Clean the county populations

# %%
# 1980
# Check header, skipfooter
countypop_1980 = pd.read_excel('/Users/tsengtammy/Dropbox/3 TT/4. Thesis/build/data/input/county_populations/e4_popest_1981_1990.xls', 
                               header=5, skipfooter=716).dropna()

start = 1980
l = list(range(start + 1, start + 11))
l = [str(i) for i in l]

countypop_1980.columns = ['County'] + l

countypop_1980 = pd.melt(countypop_1980, id_vars='County', value_vars=l, var_name='YEAR', 
                         value_name='County_Population')

# %%
countypop_1980.head()
# Out:
#       County  YEAR  County_Population
# 0    Alameda  1981          1117800.0
# 1     Alpine  1981             1090.0
# 2     Amador  1981            19800.0
# 3      Butte  1981           146800.0
# 4  Calaveras  1981            21350.0

# %%
# 1990
# Check header, skipfooter
countypop_1990 = pd.read_excel('/Users/tsengtammy/Dropbox/3 TT/4. Thesis/build/data/input/county_populations/e4_popest_1991_2000.xls', 
                               header=2, skipfooter=1).dropna()

start = 1990
l = list(range(start + 1, start + 11))
l = [str(i) for i in l]

# drop extraneous cols
countypop_1990.drop([countypop_1990.columns[1], countypop_1990.columns[-1]], axis=1, inplace=True)

countypop_1990.columns = ['County'] + l

countypop_1990 = pd.melt(countypop_1990, id_vars='County', value_vars=l, var_name='YEAR', 
                         value_name='County_Population')

# %%
# 2000
# Check header, skipfooter
countypop_2000 = pd.read_excel('/Users/tsengtammy/Dropbox/3 TT/4. Thesis/build/data/input/county_populations/e4_popest_2001_2010.xls', 
                               sheet_name=1, header=3, skipfooter=1).dropna()

start = 2000
l = list(range(start + 1, start + 11))
l = [str(i) for i in l]

# drop extraneous cols
countypop_2000.drop([countypop_2000.columns[1], countypop_2000.columns[-1]], axis=1, inplace=True)

countypop_2000.columns = ['County'] + l

countypop_2000 = pd.melt(countypop_2000, id_vars='County', value_vars=l, var_name='YEAR', 
                         value_name='County_Population')

# %%
# Now want to get county population levels in order to use Boustan's specification
# Check header, skipfooter
countypop_2010 = pd.read_excel('/Users/tsengtammy/Dropbox/3 TT/4. Thesis/build/data/input/county_populations/e4_popest_2011_2018.xls', 
                               sheet_name=1, header=3, skipfooter=1).dropna()

start = 2010
l = list(range(start + 1, start + 9))
l = [str(i) for i in l]

# drop extraneous cols
countypop_2010.drop(countypop_2010.columns[1], axis=1, inplace=True)

countypop_2010.columns = ['County'] + l

countypop_2010 = pd.melt(countypop_2010, id_vars='County', value_vars=l, var_name='YEAR', 
                         value_name='County_Population')

# %%
# AGGREGATED
countypop = countypop_1980.append(countypop_1990).append(countypop_2000).append(countypop_2010)

# %%
countypop['County'] = countypop['County'].apply(lambda x: x.strip())
countypop['YEAR'] = countypop['YEAR'].astype(int)

# %%
countypop.head()
# Out:
#       County  YEAR  County_Population
# 0    Alameda  1981          1117800.0
# 1     Alpine  1981             1090.0
# 2     Amador  1981            19800.0
# 3      Butte  1981           146800.0
# 4  Calaveras  1981            21350.0

# %%
len(countypop)
# Out:
# 2204

# %% [markdown]
# # Merge schools with the county populations

# %%
final = merged.merge(countypop, on=['County', 'YEAR'], how='left')

# %%
final.head()
# Out:
#    ADULT        CDS_CODE COUNTY DISTRICT DistrictName  ENR_TOTAL ETHNIC  \
# 0      0  01100170130401    NaN      NaN          NaN          1      1
# 1      0  01100170130401    NaN      NaN          NaN          1      2
# 2      0  01100170130401    NaN      NaN          NaN         23      2
# 3      0  01100170130401    NaN      NaN          NaN          3      3
# 4      0  01100170130401    NaN      NaN          NaN          2      4
#
#   GENDER  GR_1  GR_10        ...          CD Code  NCESDist  NCESSchool  \
# 0      M     0      0        ...          0110017   0691051       09264
# 1      F     0      0        ...          0110017   0691051       09264
# 2      M     0      5        ...          0110017   0691051       09264
# 3      M     0      0        ...          0110017   0691051       09264
# 4      M     0      0        ...          0110017   0691051       09264
#
#    StatusType   County                            District  \
# 0      Active  Alameda  Alameda County Office of Education
# 1      Active  Alameda  Alameda County Office of Education
# 2      Active  Alameda  Alameda County Office of Education
# 3      Active  Alameda  Alameda County Office of Education
# 4      Active  Alameda  Alameda County Office of Education
#
#                                School  DOC                           DOCType  \
# 0  Alameda County Juvenile Hall/Court  0.0  County Office of Education (COE)
# 1  Alameda County Juvenile Hall/Court  0.0  County Office of Education (COE)
# 2  Alameda County Juvenile Hall/Court  0.0  County Office of Education (COE)
# 3  Alameda County Juvenile Hall/Court  0.0  County Office of Education (COE)
# 4  Alameda County Juvenile Hall/Court  0.0  County Office of Education (COE)
#
#    County_Population
# 0          1437136.0
# 1          1437136.0
# 2          1437136.0
# 3          1437136.0
# 4          1437136.0
#
# [5 rows x 37 columns]

# %%
len(final)
# Out:
# 3534277

# %%
len(final[final['County_Population'].isna()])
# Out:
# 74444

# %% [markdown]
# # Open to do: Why is county NA?
# ## There are some districts in the enrollment data which are not in the identifying file (so can't the district and county names...)

# %% [markdown]
# # Deliverable Enrollment data

# %%
# Save file
final.to_csv('/Users/tsengtammy/Dropbox/3 TT/4. Thesis/build/data/output/enrollment.csv', index=False)
